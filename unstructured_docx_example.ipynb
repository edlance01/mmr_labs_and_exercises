# %%
from langchain_community.document_loaders import UnstructuredWordDocumentLoader

test_doc = "ForrestFirstRpt.docx"

#loader = UnstructuredWordDocumentLoader(test_doc, mode="elements", strategy="fast")
loader = UnstructuredWordDocumentLoader(test_doc, mode="elements")

docs = loader.load()

for a_doc in docs:
    print(f"\nDocument:{a_doc}")
# Out:
# Document:page_content='ACME BANK – PLATINUM CREDIT CARD DIVISION' metadata={'source': 'acme_bank_consolidate_performance_report.docx', 'category_depth': 0, 'emphasized_text_contents': ['ACME BANK – PLATINUM CREDIT CARD DIVISION'], 'emphasized_text_tags': ['b'], 'last_modified': '2025-01-12T09:41:42', 'page_number': 1, 'languages': ['eng'], 'filename': 'acme_bank_consolidate_performance_report.docx', 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'Title', 'element_id': '98269a7403def164024e0756be3b500b'}
#
# Document:page_content='2024 Q2 Quarterly Performance Report
# ...
